# %% [markdown]
# <img src="assets/lrlrnn_slide1.png" width="600">

# %% [markdown]
# <img src="assets/lrlrnn_slide2.png" width="600">

# %% [markdown]
# <img src="assets/lrlrnn_slide3.png" width="600">

# %% [markdown]
# <img src="assets/lrlrnn_slide4.png" width="600">

# %% [markdown]
# <img src="assets/lrlrnn_slide5.png" width="600">
